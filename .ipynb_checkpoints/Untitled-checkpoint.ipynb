# %%
import cv2 #opencv
import os
import time
import uuid

# %%
# !pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.13.0.92-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=2 in c:\users\hello\anaconda3\lib\site-packages (from opencv-python) (2.3.5)
# Downloading opencv_python-4.13.0.92-cp37-abi3-win_amd64.whl (40.2 MB)
#    ---------------------------------------- 0.0/40.2 MB ? eta -:--:--
#    -- ------------------------------------- 2.4/40.2 MB 13.6 MB/s eta 0:00:03
#    ------ --------------------------------- 6.6/40.2 MB 16.7 MB/s eta 0:00:03
#    -------- ------------------------------- 8.4/40.2 MB 14.2 MB/s eta 0:00:03
#    ------------ --------------------------- 12.6/40.2 MB 15.5 MB/s eta 0:00:02
#    --------------- ------------------------ 16.0/40.2 MB 16.0 MB/s eta 0:00:02
#    -------------------- ------------------- 20.2/40.2 MB 16.3 MB/s eta 0:00:02
#    ----------------------- ---------------- 23.9/40.2 MB 16.5 MB/s eta 0:00:01
#    --------------------------- ------------ 27.3/40.2 MB 16.6 MB/s eta 0:00:01
#    ------------------------------ --------- 30.9/40.2 MB 16.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 34.6/40.2 MB 16.8 MB/s eta 0:00:01
#    -------------------------------------- - 38.3/40.2 MB 16.9 MB/s eta 0:00:01
#    ---------------------------------------- 40.2/40.2 MB 16.3 MB/s  0:00:02
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.13.0.92

# %%
# !pip install opencv-contrib-python
# Out:
# Collecting opencv-contrib-python
#   Downloading opencv_contrib_python-4.13.0.92-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=2 in c:\users\hello\anaconda3\lib\site-packages (from opencv-contrib-python) (2.3.5)
# Downloading opencv_contrib_python-4.13.0.92-cp37-abi3-win_amd64.whl (46.5 MB)
#    ---------------------------------------- 0.0/46.5 MB ? eta -:--:--
#    -- ------------------------------------- 2.6/46.5 MB 14.2 MB/s eta 0:00:04
#    ----- ---------------------------------- 6.8/46.5 MB 17.1 MB/s eta 0:00:03
#    -------- ------------------------------- 9.7/46.5 MB 16.0 MB/s eta 0:00:03
#    ----------- ---------------------------- 13.6/46.5 MB 16.8 MB/s eta 0:00:02
#    --------------- ------------------------ 17.6/46.5 MB 16.8 MB/s eta 0:00:02
#    ------------------ --------------------- 21.0/46.5 MB 16.9 MB/s eta 0:00:02
#    --------------------- ------------------ 24.9/46.5 MB 17.0 MB/s eta 0:00:02
#    ------------------------ --------------- 28.3/46.5 MB 17.1 MB/s eta 0:00:02
#    --------------------------- ------------ 32.0/46.5 MB 17.1 MB/s eta 0:00:01
#    ------------------------------ --------- 35.9/46.5 MB 17.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 39.6/46.5 MB 17.2 MB/s eta 0:00:01
#    ------------------------------------- -- 43.3/46.5 MB 17.3 MB/s eta 0:00:01
#    ---------------------------------------  46.4/46.5 MB 17.3 MB/s eta 0:00:01
#    ---------------------------------------- 46.5/46.5 MB 16.5 MB/s  0:00:02
# Installing collected packages: opencv-contrib-python
# Successfully installed opencv-contrib-python-4.13.0.92

# %%
import cv2
print(cv2.__version__)
# Out:
# 4.13.0

# %%
IMAGES_PATH="RealTimeObjectDetection/Tensorflow/workspace/images"

# %%
labels = ['hello', 'thanks', 'yes', 'no', 'iloveyou']
number_imgs = 15

# %%
for label in labels:
    # !mkdir {'RealTimeObjectDetection/Tensorflow/workspace/images\\'+label}
    cap = cv2.VideoCapture(0)
    print('Collecting images for {}'.format(label))
    time.sleep(2)
    for imgnum in range(number_imgs):
        ret, frame = cap.read()
        imagename = os.path.join(IMAGES_PATH, label, label+'.'+'{}.jpg'.format(str(uuid.uuid1())))
        cv2.imwrite(imagename, frame)
        cv2.imshow('frame', frame)
        time.sleep(2)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    cap.release()
# Out:
# The syntax of the command is incorrect.
# Collecting images for hello
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 11
#       9 cv2.imwrite(imagename, frame)
#      10 cv2.imshow('frame', frame)
# ---> 11 time.sleep(2)
#      12 if cv2.waitKey(1) & 0xFF == ord('q'):
#      13     break
#
# KeyboardInterrupt:

# %%
import cv2
import os
import time
import uuid

for label in labels:

    path = os.path.join(IMAGES_PATH, label)

    if not os.path.exists(path):
        os.makedirs(path)

    # Open webcam
    cap = cv2.VideoCapture(0, cv2.CAP_DSHOW)

    # Check camera
    if not cap.isOpened():
        print("ERROR: Camera not opened")
        break

    print(f'Collecting images for {label}')
    time.sleep(5)

    for imgnum in range(number_imgs):

        ret, frame = cap.read()

        # Check frame capture
        if not ret:
            print("Failed to capture image")
            continue

        imgname = os.path.join(
            path,
            f'{label}.{uuid.uuid1()}.jpg'
        )

        # Save image
        cv2.imwrite(imgname, frame)

        print(f'Image saved: {imgname}')

        # Show frame
        cv2.imshow('frame', frame)

        time.sleep(1)

        # Press q to quit
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()
# Out:
# Collecting images for hello
# Image saved: RealTimeObjectDetection/Tensorflow/workspace/images\hello\hello.738cecc3-54e4-11f1-b62d-3814283fa577.jpg
# Image saved: RealTimeObjectDetection/Tensorflow/workspace/images\hello\hello.7427829b-54e4-11f1-b1e4-3814283fa577.jpg
# Image saved: RealTimeObjectDetection/Tensorflow/workspace/images\hello\hello.74c1d4a9-54e4-11f1-a80d-3814283fa577.jpg
# Image saved: RealTimeObjectDetection/Tensorflow/workspace/images\hello\hello.755c5fb0-54e4-11f1-a197-3814283fa577.jpg
# Image saved: RealTimeObjectDetection/Tensorflow/workspace/images\hello\hello.75f6ee30-54e4-11f1-aae5-3814283fa577.jpg
# Image saved: RealTimeObjectDetection/Tensorflow/workspace/images\hello\hello.76917ad6-54e4-11f1-8985-3814283fa577.jpg
# Image saved: RealTimeObjectDetection/Tensorflow/workspace/images\hello\hello.772bc695-54e4-11f1-88d0-3814283fa577.jpg
# Image saved: RealTimeObjectDetection/Tensorflow/workspace/images\hello\hello.77c5e269-54e4-11f1-b891-3814283fa577.jpg
# Image saved: RealTimeObjectDetection/Tensorflow/workspace/images\hello\hello.78604505-54e4-11f1-8297-3814283fa577.jpg
# Image saved: RealTimeObjectDetection/Tensorflow/workspace/images\hello\hello.78fa5769-54e4-11f1-93ef-3814283fa577.jpg
# Image saved: RealTimeObjectDetection/Tensorflow/workspace/images\hello\hello.79946ee0-54e4-11f1-8fd9-3814283fa577.jpg
# Image saved: RealTimeObjectDetection/Tensorflow/workspace/images\hello\hello.7a2ed87c-54e4-11f1-9c7d-3814283fa577.jpg
# Image saved: RealTimeObjectDetection/Tensorflow/workspace/images\hello\hello.7acfbccb-54e4-11f1-8ad5-3814283fa577.jpg
# Image saved: RealTimeObjectDetection/Tensorflow/workspace/images\hello\hello.7b69ffea-54e4-11f1-8605-3814283fa577.jpg
# Image saved: RealTimeObjectDetection/Tensorflow/workspace/images\hello\hello.7c0b408a-54e4-11f1-a0d4-3814283fa577.jpg
# Collecting images for thanks
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 22
#      19     break
#      21 print(f'Collecting images for {label}')
# ---> 22 time.sleep(5)
#      24 for imgnum in range(number_imgs):
#      26     ret, frame = cap.read()
#
# KeyboardInterrupt:

# %%
import cv2

cap = cv2.VideoCapture(0, cv2.CAP_DSHOW)

while True:
    ret, frame = cap.read()

    cv2.imshow('Test Camera', frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[15], line 8
#       5 while True:
#       6     ret, frame = cap.read()
# ----> 8     cv2.imshow('Test Camera', frame)
#      10     if cv2.waitKey(1) & 0xFF == ord('q'):
#      11         break
#
# error: OpenCV(4.13.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:973: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'cv::imshow'

# %%
print(os.listdir(IMAGES_PATH))
# Out:
# ['hello', 'thanks']

# %%
cap = cv2.VideoCapture(1)

# %%
cap = cv2.VideoCapture(2)

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\HELLO\RealTimeObjectDetection
